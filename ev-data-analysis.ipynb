# %% [markdown]
# # Data Analysis for Electric Vehicles

# %% [markdown]
# In this notebook I pretend to make an analysis for the file, found in the link on kaggle... Here you can se a brief analysis of ...

# %% [markdown]
# ## 1. Importing Dataset

# %% [markdown]
# Now we are importing the csv file called: "Electric Vehicle Population Data.csv" using pandas

# %%
import pandas as pd

# Loading the dataset
file_path = "data/Electric Vehicle Population Data.csv"
df = pd.read_csv(file_path)

# Showing the first rows
df.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year    Make  \
# 0  2T3YL4DV0E      King  Bellevue    WA      98005.0        2014  TOYOTA
# 1  5YJ3E1EB6K      King   Bothell    WA      98011.0        2019   TESLA
# 2  5UX43EU02S  Thurston   Olympia    WA      98502.0        2025     BMW
# 3  JTMAB3FV5R  Thurston   Olympia    WA      98513.0        2024  TOYOTA
# 4  5YJYGDEE8M    Yakima     Selah    WA      98942.0        2021   TESLA
#
#         Model                   Electric Vehicle Type  \
# 0        RAV4          Battery Electric Vehicle (BEV)
# 1     MODEL 3          Battery Electric Vehicle (BEV)
# 2          X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     MODEL Y          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           103.0
# 1            Clean Alternative Fuel Vehicle Eligible           220.0
# 2            Clean Alternative Fuel Vehicle Eligible            40.0
# 3            Clean Alternative Fuel Vehicle Eligible            42.0
# 4  Eligibility unknown as battery range has not b...             0.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  41.0       186450183
# 1        0.0                   1.0       478093654
# 2        0.0                  35.0       274800718
# 3        0.0                   2.0       260758165
# 4        0.0                  15.0       236581355
#
#               Vehicle Location                               Electric Utility  \
# 0   POINT (-122.1621 47.64441)  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 1  POINT (-122.20563 47.76144)  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2  POINT (-122.92333 47.03779)                         PUGET SOUND ENERGY INC
# 3  POINT (-122.81754 46.98876)                         PUGET SOUND ENERGY INC
# 4  POINT (-120.53145 46.65405)                                     PACIFICORP
#
#    2020 Census Tract
# 0       5.303302e+10
# 1       5.303302e+10
# 2       5.306701e+10
# 3       5.306701e+10
# 4       5.307700e+10

# %% [markdown]
# More information about the dataset

# %%
df.info()  # Show the data type for each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232230 entries, 0 to 232229
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         232230 non-null  object
#  1   County                                             232226 non-null  object
#  2   City                                               232226 non-null  object
#  3   State                                              232230 non-null  object
#  4   Postal Code                                        232226 non-null  float64
#  5   Model Year                                         232230 non-null  int64
#  6   Make                                               232230 non-null  object
#  7   Model                                              232230 non-null  object
#  8   Electric Vehicle Type                              232230 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  232230 non-null  object
#  10  Electric Range                                     232203 non-null  float64
#  11  Base MSRP                                          232203 non-null  float64
#  12  Legislative District                               231749 non-null  float64
#  13  DOL Vehicle ID                                     232230 non-null  int64
#  14  Vehicle Location                                   232219 non-null  object
#  15  Electric Utility                                   232226 non-null  object
#  16  2020 Census Tract                                  232226 non-null  float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 30.1+ MB

# %% [markdown]
# Showing general statistical values

# %%
# General statistics
print("\nSummary statistics:\n")
df.describe()
# Out:
# Summary statistics:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  232226.000000  232230.000000   232203.000000  232203.000000
# mean    98180.172044    2021.353727       46.755998     803.808973
# std      2489.407943       2.994884       84.373596    7246.597102
# min      1731.000000    1999.000000        0.000000       0.000000
# 25%     98052.000000    2020.000000        0.000000       0.000000
# 50%     98126.000000    2023.000000        0.000000       0.000000
# 75%     98375.000000    2023.000000       38.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         231749.000000    2.322300e+05       2.322260e+05
# mean              28.880979    2.343671e+08       5.298177e+10
# std               14.904503    6.831418e+07       1.507814e+09
# min                1.000000    4.385000e+03       1.001020e+09
# 25%               17.000000    2.034737e+08       5.303301e+10
# 50%               32.000000    2.512717e+08       5.303303e+10
# 75%               42.000000    2.686943e+08       5.305307e+10
# max               49.000000    4.792548e+08       5.602100e+10

# %% [markdown]
# Showing missing values

# %%
# Check for missing values
print("\nMissing values per column:\n")
print(df.isnull().sum())
# Out:
# Missing values per column:
#
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        27
# Base MSRP                                             27
# Legislative District                                 481
# DOL Vehicle ID                                         0
# Vehicle Location                                      11
# Electric Utility                                       4
# 2020 Census Tract                                      4
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# ## 2. Cleaning and Preprocessing

# %% [markdown]
# Now we are going to delete some unnecessary columns, split certain others to give us better information and so on

# %%
# Drop unnecessary columns
df.drop(columns=["VIN (1-10)", "DOL Vehicle ID"], inplace=True)

# Fill missing values for categorical columns
df["County"].fillna("Unknown", inplace=True)
df["City"].fillna("Unknown", inplace=True)
df["Postal Code"].fillna("Unknown", inplace=True)
df["Electric Utility"].fillna("Unknown", inplace=True)
df["2020 Census Tract"].fillna("Unknown", inplace=True)

# Fill missing values for numerical columns
df["Electric Range"].fillna(df["Electric Range"].median(), inplace=True)
df["Base MSRP"].fillna(df["Base MSRP"].median(), inplace=True)

# Split "Vehicle Location" into Latitude and Longitude
df[["Longitude", "Latitude"]] = df["Vehicle Location"].str.extract(r"POINT \((-?\d+\.\d+) (-?\d+\.\d+)\)")

# Convert Longitude and Latitude to numeric values
df["Longitude"] = pd.to_numeric(df["Longitude"])
df["Latitude"] = pd.to_numeric(df["Latitude"])

# Drop the original "Vehicle Location" column
df.drop(columns=["Vehicle Location"], inplace=True)

# Convert categorical columns to category type
categorical_columns = ["County", "City", "State", "Make", "Model", "Electric Vehicle Type", 
                        "Clean Alternative Fuel Vehicle (CAFV) Eligibility", "Electric Utility"]
df[categorical_columns] = df[categorical_columns].astype("category")

# Verify the changes
df.info()
# Out:
# /tmp/ipykernel_38682/1823669809.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["County"].fillna("Unknown", inplace=True)
# /tmp/ipykernel_38682/1823669809.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna("Unknown", inplace=True)
# /tmp/ipykernel_38682/1823669809.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Postal Code"].fillna("Unknown", inplace=True)
# /tmp/ipykernel_38682/1823669809.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["Postal Code"].fillna("Unknown", inplace=True)
# /tmp/ipykernel_38682/1823669809.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Electric Utility"].fillna("Unknown", inplace=True)
# /tmp/ipykernel_38682/1823669809.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["2020 Census Tract"].fillna("Unknown", inplace=True)
# /tmp/ipykernel_38682/1823669809.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["2020 Census Tract"].fillna("Unknown", inplace=True)
# /tmp/ipykernel_38682/1823669809.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Electric Range"].fillna(df["Electric Range"].median(), inplace=True)
# /tmp/ipykernel_38682/1823669809.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Base MSRP"].fillna(df["Base MSRP"].median(), inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232230 entries, 0 to 232229
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   County                                             232230 non-null  category
#  1   City                                               232230 non-null  category
#  2   State                                              232230 non-null  category
#  3   Postal Code                                        232230 non-null  object
#  4   Model Year                                         232230 non-null  int64
#  5   Make                                               232230 non-null  category
#  6   Model                                              232230 non-null  category
#  7   Electric Vehicle Type                              232230 non-null  category
#  8   Clean Alternative Fuel Vehicle (CAFV) Eligibility  232230 non-null  category
#  9   Electric Range                                     232230 non-null  float64
#  10  Base MSRP                                          232230 non-null  float64
#  11  Legislative District                               231749 non-null  float64
#  12  Electric Utility                                   232230 non-null  category
#  13  2020 Census Tract                                  232230 non-null  object
#  14  Longitude                                          232219 non-null  float64
#  15  Latitude                                           232219 non-null  float64
# dtypes: category(8), float64(5), int64(1), object(2)
# memory usage: 16.7+ MB

# %%
print("\nMissing values after cleaning:\n", df.isnull().sum())
# Out:
# Missing values after cleaning:
#  County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 481
# Electric Utility                                       0
# 2020 Census Tract                                      0
# Longitude                                             11
# Latitude                                              11
# dtype: int64

# %%
print(df[df["Legislative District"].isnull()])
print(df[df["Longitude"].isnull() | df["Latitude"].isnull()])
# Out:
#                       County            City State Postal Code  Model Year  \
# 270                     Polk           Salem    OR     97304.0        2020
# 48633                  Kings        Brooklyn    NY     11209.0        2023
# 57244   District of Columbia      Washington    DC     20002.0        2018
# 57709                 Orange  Trabuco Canyon    CA     92679.0        2023
# 61069               New York        New York    NY     10023.0        2022
# ...                      ...             ...   ...         ...         ...
# 232144            Cumberland    Fayetteville    NC     28306.0        2016
# 232186                Orange      West Point    NY     10996.0        2022
# 232200                Howard        Woodbine    MD     21797.0        2022
# 232213              Sedgwick           Derby    KS     67037.0        2017
# 232221             Penobscot          Brewer    ME      4412.0        2012
#
#           Make          Model                   Electric Vehicle Type  \
# 270      TESLA        MODEL 3          Battery Electric Vehicle (BEV)
# 48633    TESLA        MODEL Y          Battery Electric Vehicle (BEV)
# 57244    TESLA        MODEL 3          Battery Electric Vehicle (BEV)
# 57709    TESLA        MODEL Y          Battery Electric Vehicle (BEV)
# 61069      KIA            EV6          Battery Electric Vehicle (BEV)
# ...        ...            ...                                     ...
# 232144   TESLA        MODEL S          Battery Electric Vehicle (BEV)
# 232186   TESLA        MODEL Y          Battery Electric Vehicle (BEV)
# 232200   TESLA        MODEL 3          Battery Electric Vehicle (BEV)
# 232213    FORD         FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 232221  TOYOTA  PRIUS PLUG-IN  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 270               Clean Alternative Fuel Vehicle Eligible           322.0
# 48633   Eligibility unknown as battery range has not b...             0.0
# 57244             Clean Alternative Fuel Vehicle Eligible           215.0
# 57709   Eligibility unknown as battery range has not b...             0.0
# 61069   Eligibility unknown as battery range has not b...             0.0
# ...                                                   ...             ...
# 232144            Clean Alternative Fuel Vehicle Eligible           210.0
# 232186  Eligibility unknown as battery range has not b...             0.0
# 232200  Eligibility unknown as battery range has not b...             0.0
# 232213              Not eligible due to low battery range            21.0
# 232221              Not eligible due to low battery range             6.0
#
#         Base MSRP  Legislative District  \
# 270           0.0                   NaN
# 48633         0.0                   NaN
# 57244         0.0                   NaN
# 57709         0.0                   NaN
# 61069         0.0                   NaN
# ...           ...                   ...
# 232144        0.0                   NaN
# 232186        0.0                   NaN
# 232200        0.0                   NaN
# 232213        0.0                   NaN
# 232221        0.0                   NaN
#
#                              Electric Utility 2020 Census Tract  Longitude  \
# 270     NON WASHINGTON STATE ELECTRIC UTILITY     41053005204.0 -123.05598
# 48633   NON WASHINGTON STATE ELECTRIC UTILITY     36047013800.0  -74.03151
# 57244   NON WASHINGTON STATE ELECTRIC UTILITY     11001007903.0  -76.99336
# 57709   NON WASHINGTON STATE ELECTRIC UTILITY      6059032043.0 -117.59028
# 61069   NON WASHINGTON STATE ELECTRIC UTILITY     36061015102.0  -73.98228
# ...                                       ...               ...        ...
# 232144  NON WASHINGTON STATE ELECTRIC UTILITY     37051000500.0  -78.89953
# 232186  NON WASHINGTON STATE ELECTRIC UTILITY     36071013600.0  -73.95502
# 232200  NON WASHINGTON STATE ELECTRIC UTILITY     24027604004.0  -77.06409
# 232213  NON WASHINGTON STATE ELECTRIC UTILITY     20173009801.0  -97.27013
# 232221  NON WASHINGTON STATE ELECTRIC UTILITY     23019004300.0  -68.76433
#
#         Latitude
# 270     44.94796
# 48633   40.62956
# 57244   38.89608
# 57709   33.66169
# 61069   40.77513
# ...          ...
# 232144  35.02049
# 232186  41.39523
# 232200  39.35812
# 232213  37.54531
# 232221  44.79559
#
# [481 rows x 16 columns]
#          County        City State Postal Code  Model Year       Make  \
# 73713   Pacific  Long Beach    WA     98634.0        2017        KIA
# 78436   Pacific  Long Beach    WA     98634.0        2022      TESLA
# 151574  Pacific  Long Beach    WA     98634.0        2022  CHEVROLET
# 153955  Pacific  Long Beach    WA     98634.0        2025  CHEVROLET
# 186473  Pacific  Long Beach    WA     98634.0        2017     TOYOTA
# 190110  Pacific  Long Beach    WA     98634.0        2023       JEEP
# 221984  Unknown     Unknown    AE     Unknown        2019        BMW
# 222615  Pacific  Long Beach    WA     98634.0        2017    HYUNDAI
# 225662  Unknown     Unknown    BC     Unknown        2017      TESLA
# 227478  Unknown     Unknown    AP     Unknown        2018        BMW
# 227979  Unknown     Unknown    NS     Unknown        2021      TESLA
#
#               Model                   Electric Vehicle Type  \
# 73713       SOUL EV          Battery Electric Vehicle (BEV)
# 78436       MODEL Y          Battery Electric Vehicle (BEV)
# 151574      BOLT EV          Battery Electric Vehicle (BEV)
# 153955   EQUINOX EV          Battery Electric Vehicle (BEV)
# 186473  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 190110     WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 221984         530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 222615       SONATA  Plug-in Hybrid Electric Vehicle (PHEV)
# 225662      MODEL X          Battery Electric Vehicle (BEV)
# 227478         530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 227979      MODEL 3          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 73713             Clean Alternative Fuel Vehicle Eligible            93.0
# 78436   Eligibility unknown as battery range has not b...             0.0
# 151574  Eligibility unknown as battery range has not b...             0.0
# 153955  Eligibility unknown as battery range has not b...             0.0
# 186473              Not eligible due to low battery range            25.0
# 190110              Not eligible due to low battery range            21.0
# 221984              Not eligible due to low battery range            16.0
# 222615              Not eligible due to low battery range            27.0
# 225662            Clean Alternative Fuel Vehicle Eligible           200.0
# 227478              Not eligible due to low battery range            16.0
# 227979  Eligibility unknown as battery range has not b...             0.0
#
#         Base MSRP  Legislative District  \
# 73713     32250.0                  19.0
# 78436         0.0                  19.0
# 151574        0.0                  19.0
# 153955        0.0                  19.0
# 186473        0.0                  19.0
# 190110        0.0                  19.0
# 221984    53400.0                   NaN
# 222615        0.0                  19.0
# 225662        0.0                   NaN
# 227478    52650.0                   NaN
# 227979        0.0                   NaN
#
#                                          Electric Utility 2020 Census Tract  \
# 73713   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...     53049950501.0
# 78436   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...     53049950600.0
# 151574  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...     53049950600.0
# 153955  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...     53049950702.0
# 186473  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...     53049950600.0
# 190110  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...     53049950600.0
# 221984                                            Unknown           Unknown
# 222615  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...     53049950501.0
# 225662                                            Unknown           Unknown
# 227478                                            Unknown           Unknown
# 227979                                            Unknown           Unknown
#
#         Longitude  Latitude
# 73713         NaN       NaN
# 78436         NaN       NaN
# 151574        NaN       NaN
# 153955        NaN       NaN
# 186473        NaN       NaN
# 190110        NaN       NaN
# 221984        NaN       NaN
# 222615        NaN       NaN
# 225662        NaN       NaN
# 227478        NaN       NaN
# 227979        NaN       NaN

# %% [markdown]
# # Breakpoint

# %%
# df["Longitude"].fillna(df.groupby("City")["Longitude"].transform("mean"), inplace=True)
# df["Latitude"].fillna(df.groupby("City")["Latitude"].transform("mean"), inplace=True)

# %%
# df["Legislative District"].fillna(df.groupby("City")["Legislative District"].transform(lambda x: x.mode()[0] if not x.mode().empty else None), inplace=True)

# %%
# df["Legislative District"].fillna("Unknown", inplace=True)

# %%
# print("\nMissing values after cleaning:\n", df.isnull().sum())
